# %%
import pandas as pd
from collections import Counter
from nltk.corpus import stopwords

# %%
# Funktion zum Einlesen der Texte.
def text_vorbereiten(dateiname):
    with open('daten/' + dateiname, 'r') as f:
        lt = f.read()
    lt = lt.replace('\n', ' ').replace('.', ' ').replace(',', ' ').replace('!', '').replace('?', '').replace(';', '')
    lt = lt.replace('„', '').replace('“', '').replace('"', '')
    lt = lt.replace('  ', ' ')
    return lt

# %%
df = pd.read_csv('länderübersicht.csv', index_col='index')

# %%
df['liedtext'] = df['text'].apply(text_vorbereiten)
df
# Out:
#                                               englisch  \
# index
# Afghanistan                                Afghanistan
# Ägypten                                          Egypt
# Albanien                                       Albania
# Algerien                                       Algeria
# Andorra                                        Andorra
# Angola                                          Angola
# Antigua und Barbuda                Antigua and Barbuda
# Äquatorialguinea                     Equatorial Guinea
# Argentinien                                  Argentina
# Armenien                                       Armenia
# Aserbaidschan                               Azerbaijan
# Äthiopien                                     Ethiopia
# Australien                                   Australia
# Bahamas                                        Bahamas
# Bahrain                                        Bahrain
# Bangladesch                                 Bangladesh
# ...

# %%
df.loc['Vereinigte Staaten']['liedtext']
# Out:
# 'O sagt könnt ihr sehen im frühen Licht der Morgendämmerung was wir so stolz grüßten im letzten Schimmer der Abenddämmerung Dessen breite Streifen und helle Sterne die gefahrvollen Kämpfe hindurch über den Wällen die wir bewachten so stattlich wehten Und der Raketen grelles rotes Licht die in der Luft explodierenden Bomben bewiesen die Nacht hindurch dass unsere Flagge noch da war Oh sagt weht dieses sternenbesetzte Banner noch immer über dem Land der Freien und der Heimat der Tapferen Am Ufer noch eben zu sehen durch die Nebel der Tiefe Wo des Feindes hochmütiges Heer in fürchtender Stille ruht Was ist es was die Brise über dem sich auftürmenden Steilhang Wenn sie zuckend weht halb verbirgt halb enthüllt Nun erfasst es den Schimmer des ersten Morgenstrahls In voller Pracht reflektiert scheint es nun im (Licht-)Strom ’s ist das Sternenbanner O möge es lange wehen Über dem Land der Freien und der Heimat der Tapferen Und wo ist die Gruppe die sich rühmend geschworen dass die Verwüstung
# ...

# %%
# Welche Wörter kommen in den Hymnen besonder oft vor? 
alle_texte = df['liedtext'].sum()
word_freqs = Counter(alle_texte.split())
df_wörter = pd.DataFrame.from_dict(word_freqs, orient='index')

# %%
stopWords = set(stopwords.words('german'))
df_wörter[~df_wörter.index.str.lower().isin(stopWords)].sort_values(by=0, ascending=False).head(30)
# Out:
#               0
# Land        239
# Gott        137
# Freiheit    127
# Vaterland    93
# Heimat       73
# immer        72
# Volk         69
# Nation       68
# unserer      65
# Oh           57
# Ruhm         55
# Liebe        53
# dass         52
# Welt         51
# Lasst        50
# sei          49
# Frieden      49
# Flagge       48
# Heimatland   46
# Leben        46
# leben        41
# Blut         41
# O            41
# Himmel       40
# frei         40
# Sonne        38
# Herz         36
# Herzen       35
# Ehre         35
# Glück        34
